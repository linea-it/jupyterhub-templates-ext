# %% [markdown]
# # Planetas do Sistema Solar
#
# Template para trabalhar com dados dos planetas (tabelas, gráficos, etc.).

# %%
planets = [
    ('Mercúrio', 0.39, 0.06),
    ('Vénus', 0.72, 0.82),
    ('Terra', 1.00, 1.00),
    ('Marte', 1.52, 0.11),
    ('Júpiter', 5.20, 318),
    ('Saturno', 9.54, 95),
    ('Urano', 19.2, 14),
    ('Neptuno', 30.1, 17),
]
# distância média (UA), massa (Terra=1)

# %%
import pandas as pd
df = pd.DataFrame(planets, columns=['Planeta', 'Distância (UA)', 'Massa (Terra=1)'])
df

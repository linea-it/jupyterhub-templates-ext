# %% [markdown]
# # Análise de dados – template
#
# Substitua o caminho do ficheiro e execute as células.

# %%
import pandas as pd

# df = pd.read_csv('seu_ficheiro.csv')
# df.head()

# %%
# df.describe()
# df.info()

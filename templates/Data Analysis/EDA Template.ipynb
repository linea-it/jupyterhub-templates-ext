# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Template para análise exploratória: carregar dados, estatísticas e visualizações.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# path = 'dados.csv'
# df = pd.read_csv(path)

# %%
# df.hist(figsize=(12, 8))
# plt.tight_layout()
# plt.show()
